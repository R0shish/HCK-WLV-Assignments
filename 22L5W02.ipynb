# %% [markdown]
# <a href="https://colab.research.google.com/github/R0shish/HCK-WLV-Assignments/blob/colaboratory/22L5W02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week-2-Workshops
# ## Instructions and Requirements:
# This workshops is | divided into five different sections:
#   *    Connect drive, or upload your datasets in the colab
#   * Open and Load the datasets into google colab Read and display the datasets using pandas Questions to answer
#   * Data transfomation(Basic)
#   * Basic Descriptive Statistical Anlysis(Measurement of Central Tendency) and(Measurement of Dispersion)
#   * Basic Data Visualization using different plots techniques
#   * Data Analysis and Visualization
#   ## Requirements:
#     *   Notebook Environment(Jupyter or Google Colab)
#
# *   Author: Siman Giri
# *   Co-Author: Anmol Adhikari

# %% [markdown]
# # Section 0
# Connect drive, or upload datasets in the colab
# 1. Necessary imports

# %%
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_datasets = "/content/drive/MyDrive/Concepts and Technology of AI/bank.csv"

# %%
#Necessary imports:
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Section 1
# Open and Load the datasets into google colab
# Read and display the dataets using pandas
# Questions to answer:

# %% [markdown]
# 1. Load the provided dataset in google collab and import data in pandas dataframe.

# %%
df = pd.read_csv(path_datasets)
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %% [markdown]
# 2. Show first five rows of the dataframe.

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %% [markdown]
# 3. Show Last five rows of the dataframe.

# %%
df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %% [markdown]
# 4. Check info of the columns in the datasets.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# 5. Check for null and unique values in the columns having object data type.

# %%
df.isnull()
# Out:
#          age    job  marital  education  default  balance  housing   loan  \
# 0      False  False    False      False    False    False    False  False
# 1      False  False    False      False    False    False    False  False
# 2      False  False    False      False    False    False    False  False
# 3      False  False    False      False    False    False    False  False
# 4      False  False    False      False    False    False    False  False
# ...      ...    ...      ...        ...      ...      ...      ...    ...
# 45206  False  False    False      False    False    False    False  False
# 45207  False  False    False      False    False    False    False  False
# 45208  False  False    False      False    False    False    False  False
# 45209  False  False    False      False    False    False    False  False
# 45210  False  False    False      False    False    False    False  False
#
#        contact    day  month  duration  campaign  pdays  previous  poutcome  \
# 0        False  False  False     False     False  False     False     False
# 1        False  False  False     False     False  False     False     False
# 2        False  False  False     False     False  False     False     False
# 3        False  False  False     False     False  False     False     False
# 4        False  False  False     False     False  False     False     False
# ...        ...    ...    ...       ...       ...    ...       ...       ...
# 45206    False  False  False     False     False  False     False     False
# 45207    False  False  False     False     False  False     False     False
# 45208    False  False  False     False     False  False     False     False
# 45209    False  False  False     False     False  False     False     False
# 45210    False  False  False     False     False  False     False     False
#
#            y
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 45206  False
# 45207  False
# 45208  False
# 45209  False
# 45210  False
#
# [45211 rows x 17 columns]

# %%
for objects in df:
  if objects in ["job", "martial", "education", "default", "housing","loan", "contact", "month","poutcome","y"]:
      print(objects, end=": ")
      print(df[objects].unique())
# Out:
# job: ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# education: ['tertiary' 'secondary' 'unknown' 'primary']
# default: ['no' 'yes']
# housing: ['yes' 'no']
# loan: ['no' 'yes']
# contact: ['unknown' 'cellular' 'telephone']
# month: ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# poutcome: ['unknown' 'failure' 'other' 'success']
# y: ['no' 'yes']

# %% [markdown]
# # Section:2
# Data transfomation
# 1. Convert housing, default, loan and the target variable y into binary; yes - 1, no - 0
# 2. (perform this task with all the columns having datatype object)
# 3. create a new column duration_minutes whose values should be based on the values present in the duration column transformed from seconds to minutes

# %%
# Quesiton no 1
for objects in df:
  if objects in ["housing", "default", "loan", "y"]:
    df[objects] = df[objects].map({"yes":1, "no":0})
df
# Out:
#        age           job   marital  education  default  balance  housing  \
# 0       58    management   married   tertiary        0     2143        1
# 1       44    technician    single  secondary        0       29        1
# 2       33  entrepreneur   married  secondary        0        2        1
# 3       47   blue-collar   married    unknown        0     1506        1
# 4       33       unknown    single    unknown        0        1        0
# ...    ...           ...       ...        ...      ...      ...      ...
# 45206   51    technician   married   tertiary        0      825        0
# 45207   71       retired  divorced    primary        0     1729        0
# 45208   72       retired   married  secondary        0     5715        0
# 45209   57   blue-collar   married  secondary        0      668        0
# 45210   37  entrepreneur   married  secondary        0     2971        0
#
#        loan    contact  day month  duration  campaign  pdays  previous  \
# 0         0    unknown    5   may       261         1     -1         0
# 1         0    unknown    5   may       151         1     -1         0
# 2         1    unknown    5   may        76         1     -1         0
# 3         0    unknown    5   may        92         1     -1         0
# 4         0    unknown    5   may       198         1     -1         0
# ...     ...        ...  ...   ...       ...       ...    ...       ...
# 45206     0   cellular   17   nov       977         3     -1         0
# 45207     0   cellular   17   nov       456         2     -1         0
# 45208     0   cellular   17   nov      1127         5    184         3
# 45209     0  telephone   17   nov       508         4     -1         0
# 45210     0   cellular   17   nov       361         2    188        11
#
#       poutcome  y  duration_minutes
# 0      unknown  0          4.350000
# 1      unknown  0          2.516667
# 2      unknown  0          1.266667
# 3      unknown  0          1.533333
# 4      unknown  0          3.300000
# ...        ... ..               ...
# 45206  unknown  1         16.283333
# 45207  unknown  1          7.600000
# 45208  success  1         18.783333
# 45209  unknown  0          8.466667
# 45210    other  0          6.016667
#
# [45211 rows x 18 columns]

# %%
# Quesiton no 3
df["duration_minutes"] = df["duration"] / 60
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 0        unknown    5   may       261         1     -1         0  unknown
# 1        unknown    5   may       151         1     -1         0  unknown
# 2        unknown    5   may        76         1     -1         0  unknown
# 3        unknown    5   may        92         1     -1         0  unknown
# 4        unknown    5   may       198         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 45206   cellular   17   nov       977         3     -1         0  unknown
# 45207   cellular   17   nov       456         2     -1         0  unknown
# 45208   cellular   17   nov      1127         5    184         3  success
# 45209  telephone   17   nov       508         4     -1         0  unknown
# 45210   cellular   17   nov       361         2    188        11    other
#
#          y  duration_minutes
# 0       no          4.350000
# 1       no          2.516667
# 2       no          1.266667
# 3       no          1.533333
# 4       no          3.300000
# ...    ...               ...
# 45206  yes         16.283333
# 45207  yes          7.600000
# 45208  yes         18.783333
# 45209   no          8.466667
# 45210   no          6.016667
#
# [45211 rows x 18 columns]

# %% [markdown]
# # Section 3
# Basic Descriptive Statistical Anlysis
# 1. Carryout initial Data Analysis Sum, mean, mode, median, max, min

# %%
# Sum
for objects in df:
  if objects in ["age", "balance", "day", "pday", "campaign", "duration", "duration_minutes"]:
    print("Sum of " + objects, end=": ")
    print(df[objects].sum())
# Out:
# Sum of age: 1850767
# Sum of balance: 61589682
# Sum of day: 714624
# Sum of duration: 11671811
# Sum of duration_minutes: 194530.18333333335

# %%
# Mean
for objects in df:
  if objects in ["age", "balance", "day", "pday", "campaign", "duration", "duration_minutes"]:
    print("Mean of " + objects, end=": ")
    print(df[objects].mean())
# Out:
# Mean of age: 40.93621021432837
# Mean of balance: 1362.2720576850766
# Mean of day: 15.80641879188693
# Mean of duration: 258.1630797814691
# Mean of duration_minutes: 4.302717996357819

# %%
# Median
for objects in df:
  if objects in ["age", "balance", "day", "pday", "campaign", "duration", "duration_minutes"]:
    print("Median of " + objects, end=": ")
    print(df[objects].median())
# Out:
# Median of age: 39.0
# Median of balance: 448.0
# Median of day: 16.0
# Median of duration: 180.0
# Median of duration_minutes: 3.0

# %%
# Max
for objects in df:
  if objects in ["age", "balance", "day", "pday", "campaign", "duration", "duration_minutes"]:
    print("Max of " + objects, end=": ")
    print(df[objects].max())
# Out:
# Max of age: 95
# Max of balance: 102127
# Max of day: 31
# Max of duration: 4918
# Max of duration_minutes: 81.96666666666667

# %%
# Min
for objects in df:
  if objects in ["age", "balance", "day", "pday", "campaign", "duration", "duration_minutes"]:
    print("Min of " + objects, end=": ")
    print(df[objects].min())
# Out:
# Min of age: 18
# Min of balance: -8019
# Min of day: 1
# Min of duration: 0
# Min of duration_minutes: 0.0

# %%
# Mode
for objects in df:
  if objects in ["age", "balance", "day", "pday", "campaign", "duration", "duration_minutes"]:
    print("Mode of " + objects, end=": ")
    print(df[objects].mode().values[0])
# Out:
# Mode of age: 32
# Mode of balance: 0
# Mode of day: 20
# Mode of duration: 124
# Mode of campaign: 1
# Mode of duration_minutes: 2.066666666666667

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous  duration_minutes
# count  45211.000000  45211.000000      45211.000000
# mean      40.197828      0.580323          4.302718
# std      100.128746      2.303441          4.292130
# min       -1.000000      0.000000          0.000000
# 25%       -1.000000      0.000000          1.716667
# 50%       -1.000000      0.000000          3.000000
# 75%       -1.000000      0.000000          5.316667
# max      871.000000    275.000000         81.966667

# %% [markdown]
# # Section 4
# Basic Datavisualization
# 1. Plot histograms of age
# 2. plot in bar showing number of subscriptions according to level of education
# 3. plot in bar showing number of subscriptions according to job
# 1. Plot bar chart for age,balance
# 2. Plot histograms of balance

# %%
# Question 1
df.age.hist()

# %%
# Question 2
pd.crosstab(df.education, df.y).plot(kind="bar")
plt.title("Number of Subcription accroding to level of education")
plt.xlabel("Level of Education")
plt.ylabel("Number of Subscription")
# Out:
# Text(0, 0.5, 'Number of Subscription')

# %%
# Question 3
pd.crosstab(df.job, df.y).plot(kind="bar")
plt.title("Number of Subcription accroding to job")
plt.xlabel("Job")
plt.ylabel("Number of Subscription")
# Out:
# Text(0, 0.5, 'Number of Subscription')

# %%
# Question 5
df.balance.hist()

# %% [markdown]
# # Section 5
# Data Visualization and Analysis
# 1. Check number of acceptance and rejection in target variable y and plot in pie chart
# 2. Check Total number of clients who subscribed according to the marital status
# 3. Check Total number of clients on the basis of education
# 4. Check the general level of education of people based on the provided data set
# 5. Calculate the ratio who said yes according to their education

# %%
# Question 1
df["y"].value_counts().plot.pie()

# %%
# Question 2
pd.crosstab(df.marital, df.y).plot(kind="bar")
plt.title("Total number of clients who subscribed according to the marital status")
plt.xlabel("Marital Status")
plt.ylabel("Number of Subscription")
# Out:
# Text(0, 0.5, 'Number of Subscription')

# %%
# Question 3
df.education.value_counts().plot.bar()

# %%
# Question 4
pd.crosstab(df.education, df.y).plot(kind="bar")

# %%
# Question 5
x = df.groupby("education")["y"].count()
y = df.query("y==1").groupby("education")["y"].count()
print(y/x)
# Out:
# education
# primary      0.086265
# secondary    0.105594
# tertiary     0.150064
# unknown      0.135703
# Name: y, dtype: float64

# %% [markdown]
# # Further Practice Tasks
# 1. Check how many categorical samples are there in column 'Target'
# 2. Visualise count plot
# # Split DataSet into 2 parts
# 1. Numeric type and Categorical type
# 2. Check Age Class Distribution and also visualize
# 3. Check Marital Feature Distribution and also visualize
# 4. Relation between top 5 client jobs and their ages and also visualize
# 5. Bar plot for all categorical variables in the dataset
